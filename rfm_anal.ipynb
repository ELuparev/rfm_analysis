# %% [markdown]
# ### Проект: "RFM сегментация пользователей"
#
# ### Цель проекта: отбор наиболее лояльных пользователей для акции в следующем месяце

# %% [markdown]
# В данном проекте будет использован датасет маркетплейса по покупкам пользователей за период с 2021-01	по 2022-04.
#
# Описание данных (75059 наблюдений, 4 поля):
#
# * transaction_id - айди транзакции;
# * created_at - время создания заказа;
# * user_id - айди пользователя;
# * amount - сумма заказа, руб.

# %% [markdown]
# Обновим sqlite3 до последней версии

# %%
# !wget https://www.sqlite.org/src/tarball/sqlite.tar.gz?r=release -O sqlite.tar.gz
# !tar xzf sqlite.tar.gz
# %cd sqlite/
# !./configure
# !make sqlite3.c
# %cd /content
# !npx degit coleifer/pysqlite3 -f
# !cp sqlite/sqlite3.[ch] .
# !python setup.py build_static build
# !cp build/lib.linux-x86_64-3.6/pysqlite3/_sqlite3.cpython-36m-x86_64-linux-gnu.so \
    /usr/lib/python3.6/lib-dynload/_sqlite3.cpython-36m-x86_64-linux-gnu.so

# %% [markdown]
# Подключим необходимые библиотеки для дальнейшей работы

# %%
import pandas as pd
import sqlite3
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sqlite3.sqlite_version # все окей
# Out:
# '3.31.1'

# %% [markdown]
# Найдем путь к файлам на гугл-диске

# %%
# !ls /content/drive/MyDrive/datasets/marketplace_users/
# Out:
# transactions.csv  users.csv

# %%
trans = pd.read_csv('drive/MyDrive/datasets/marketplace_users/transactions.csv')

# %% [markdown]
# Считаем данные и убедимся, что все __ок__

# %%
trans.head()
# Out:
#    Unnamed: 0                    transaction_id           created_at  \
# 0           1  e8152ef72822baae14866c30d5155ec8  2022-04-27 21:58:28
# 1           2  9305700c4b7364cda47edaf6990ab7bc  2022-02-19 14:57:37
# 2           3  3e89681d4f3d62beed4db199c719da8f  2021-12-09 20:40:10
# 3           4  50c2d79c35513eaa1864999106f91dc3  2022-04-30 09:09:54
# 4           5  ce34444f31415fe2993d5b1dbe2ac846  2021-11-05 05:45:31
#
#             user_id  amount
# 0  e1d22453e5f60161     213
# 1  e1d22453e5f60161     128
# 2  e1d22453e5f60161     391
# 3  e08aa20152ca92c7     163
# 4  e08aa20152ca92c7     329

# %%
trans.shape

# %%
trans.dtypes
# Out:
# Unnamed: 0         int64
# transaction_id    object
# created_at        object
# user_id           object
# amount             int64
# dtype: object

# %% [markdown]
# __Распарсим дату__

# %%
trans['created_at'] = pd.to_datetime(trans['created_at'],format='%Y/%m/%d %H:%M:%S')

# %%
trans.dtypes
# Out:
# Unnamed: 0                 int64
# transaction_id            object
# created_at        datetime64[ns]
# user_id                   object
# amount                     int64
# dtype: object

# %% [markdown]
# Создадим подключение к SQLite3 для удобной трансформации данных

# %%
conn = sqlite3.connect('db')
cur = conn.cursor()

# %%
def select(sql):
  return pd.read_sql(sql, conn)

# %%
trans.to_sql('transactions', conn, index=False, if_exists='replace')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %% [markdown]
# Взглянем на количество заказов по месяцам:

# %%
sql = ''' select

date(t.created_at, 'start of month') as month,
count(*)

from transactions t
group by date(t.created_at, 'start of month')
order by month
'''

# %%
select(sql) # используем данные с даты 2021-11-01, другими словами, будем опираться на полугодовые данные по пользователям
# Out:
#          month  count(*)
# 0   2021-01-01       217
# 1   2021-02-01       635
# 2   2021-03-01      1050
# 3   2021-04-01      1497
# 4   2021-05-01      2154
# 5   2021-06-01      2658
# 6   2021-07-01      3313
# 7   2021-08-01      4041
# 8   2021-09-01      4713
# 9   2021-10-01      5684
# 10  2021-11-01      6653
# 11  2021-12-01      8238
# 12  2022-01-01      8760
# 13  2022-02-01      8088
# 14  2022-03-01      8805
# 15  2022-04-01      8553

# %%
sql = ''' select

max(t.created_at)

from transactions t
'''

# %%
select(sql)
# Out:
#      max(t.created_at)
# 0  2022-04-30 23:59:45

# %% [markdown]
# Последняя покупка была 2022-04-30, следовательно, дату "сегодня" для дальнейшего анализа установим как 2022-05-01

# %%
sql = '''

select 

t.user_id,
max(t.created_at) as last_purchase,
date('2022-05-01') as today,
julianday(date('2022-05-01')) - julianday(max(t.created_at)) as recency,
count(distinct t.transaction_id) as frequency,
sum(t.amount) as monetary

from transactions t

where t.created_at > "2021-11-01 00:00:01" 
group by t.user_id
'''

# %%
t = select(sql)

# %% [markdown]
# Получили таблицу с дополнительными полями:
# * _last_purchase_ (последняя покупка клиента);
# * _today_ (дата "сегодня");
# * _recency_ (как давно была последняя покупка);
# * _frequency_ (общее число покупок за полгода);
# * _monetary_ (общая сумма потраченных денег за полгода, руб)

# %%
t.head()
# Out:
#             user_id        last_purchase       today     recency  frequency  \
# 0  00027f46f0e4e4c4  2022-04-22 20:12:39  2022-05-01    8.157882          9
# 1  00054380944abc67  2022-03-11 02:48:43  2022-05-01   50.882836          5
# 2  0014d31816486e07  2022-04-07 17:06:59  2022-05-01   23.286817          9
# 3  00162b63a0b32f04  2022-03-16 09:20:28  2022-05-01   45.610787          4
# 4  0021a1b1ae8e71cb  2021-11-22 00:34:04  2022-05-01  159.976343          1
#
#    monetary
# 0     28289
# 1     10709
# 2      3599
# 3      3017
# 4      3463

# %%
t['r'] = 5 - (pd.qcut(t['recency'], 4, labels=False) + 1)

# %%
t['f'] = pd.qcut(t['frequency'], 4, labels=False, duplicates='drop') + 1

# %%
t['f'].value_counts()
# Out:
# 1    2357
# 3    1614
# 4    1466
# 2    1113
# Name: f, dtype: int64

# %%
def freq_dist(f_count):
  if f_count in [1, 2, 3, 4, 5]:
    return 1
  if f_count in [6, 7, 8, 9, 10]:
    return 2
  if f_count in [11, 12, 13, 14, 15, 16, 17, 18]:
    return 3
  else:
    return 4

# %%
t['f'] = t['frequency'].apply(freq_dist)

# %%
t.groupby('f')['frequency'].agg(['mean','count'])
# Out:
#         mean  count
# f
# 1   2.787320   3470
# 2   7.624535   1614
# 3  13.874608    957
# 4  27.192534    509

# %%
t['m'] = pd.qcut(t['monetary'],4,labels=False) + 1

# %%
# усредненный скор клиента
t['rfm_score'] = ((t['r'] + t['f'] + t['m']) / 3).round(2)

# %%
# "классический" скор клиента
t['rfm_score_conc'] = t['r'].astype(str) + t['f'].astype(str) + t['m'].astype(str)

# %%
t
# Out:
#                user_id        last_purchase       today     recency  \
# 0     00027f46f0e4e4c4  2022-04-22 20:12:39  2022-05-01    8.157882
# 1     00054380944abc67  2022-03-11 02:48:43  2022-05-01   50.882836
# 2     0014d31816486e07  2022-04-07 17:06:59  2022-05-01   23.286817
# 3     00162b63a0b32f04  2022-03-16 09:20:28  2022-05-01   45.610787
# 4     0021a1b1ae8e71cb  2021-11-22 00:34:04  2022-05-01  159.976343
# ...                ...                  ...         ...         ...
# 6545  ffc62f7b0a060911  2022-04-22 07:16:20  2022-05-01    8.696991
# 6546  ffc8e3e87da64d5c  2022-04-16 19:40:54  2022-05-01   14.179931
# 6547  fff1dcff30af717a  2022-02-01 19:02:46  2022-05-01   88.206412
# 6548  fffc9b98162778fd  2022-03-31 04:25:16  2022-05-01   30.815787
# 6549  ffff9f67ecd58c4c  2022-02-05 20:21:26  2022-05-01   84.151782
#
#       frequency  monetary  r  f  m  rfm_score rfm_score_conc
# 0             9     28289  3  2  4       3.00            324
# 1             5     10709  1  1  3       1.67            113
# 2             9      3599  2  2  2       2.00            222
# 3             4      3017  2  1  2       1.67            212
# 4             1      3463  1  1  2       1.33            112
# ...         ...       ... .. .. ..        ...            ...
# 6545         12     18535  3  3  4       3.33            334
# 6546          4      3834  3  1  2       2.00            312
# 6547          1       400  1  1  1       1.00            111
# 6548          3      7373  2  1  3       2.00            213
# 6549          3      1031  1  1  1       1.00            111
#
# [6550 rows x 11 columns]

# %% [markdown]
# Отберем "лучших" клиентов по получившемуся анализу

# %%
best_users = t.query('rfm_score == 4.0') # or 'rfm_score_conc == 444'

# %%
best_users.shape
# Out:
# (300, 11)

# %%
best_users[['recency', 'frequency', 'monetary']].mean()
# Out:
# recency          3.057272
# frequency       29.660000
# monetary     36128.073333
# dtype: float64

# %% [markdown]
# Таким образом, получили таблицу с __300__ id клиентов с самым высоким __rfm_score__, которые:
#
# * больше тратят (в среднем __36128__ руб. за период),
# * чаще покупают (в среднем __29__ раз за период/каждые __6.21__ дня),
# * последняя покупка была недавно (в среднем __3,5__ дня назад).
